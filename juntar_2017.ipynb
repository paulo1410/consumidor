# %%
import pandas as pd
import numpy as np

# %%
file1 = "../2017_p1.xlsx"
file2 = "../2017_p2.xlsx"

# %%
df1 = pd.read_excel(file1)

# %%
df1
# Out:
#                 Protocolo    Data Finalização  \
# 0       20171200001055820 2017-12-31 23:40:29
# 1       20171200001059152 2017-12-31 23:25:01
# 2       20171200001053020 2017-12-31 22:48:42
# 3       20171200001075260 2017-12-31 22:07:08
# 4       20171200001083060 2017-12-31 21:57:23
# ...                   ...                 ...
# 220312  20170600000809072 2017-07-26 21:47:39
# 220313  20170700000851800 2017-07-26 21:46:38
# 220314  20170700000839688 2017-07-26 21:43:45
# 220315  20170600000814300 2017-07-26 21:43:38
# 220316  20170700000843020 2017-07-26 21:35:56
#
#                                         Fornecedor UF do Consumidor  \
# 0                              Walmart Brasil Ltda               SP
# 1                    Banco Santander (Brasil) S.A.               SP
# 2       Amil Assistencia Médica Internacional S.A.               SP
# 3                                         Tim S.A.               PE
# ...

# %%
df2 = pd.read_excel(file2)

# %%
df2
# Out:
#                 Protocolo    Data Finalização  \
# 0       20170700000853848 2017-07-26 21:35:36
# 1       20170700000855088 2017-07-26 21:35:35
# 2       20170700000832728 2017-07-26 21:35:24
# 3       20170700000853872 2017-07-26 21:35:06
# 4       20170700000843300 2017-07-26 21:33:21
# ...                   ...                 ...
# 250426  20161200000544592 2017-01-01 00:01:50
# 250427  20161200000547380 2017-01-01 00:01:49
# 250428  20161200000548640 2017-01-01 00:01:47
# 250429  20161200000550460 2017-01-01 00:01:46
# 250430  20161100000543512 2017-01-01 00:01:46
#
#                                                Fornecedor UF do Consumidor  \
# 0                                              Serasa S/A               SP
# 1                                              Serasa S/A               SP
# 2                            BP Promotora de Vendas Ltda.               AL
# 3       BOA VISTA SERVIÇOS S.A. - SCPC SERVIÇO CENTRAL...               SP
# ...

# %%
df = pd.concat([df1,df2])

# %%
len(df1)+len(df2)

# %%
df
# Out:
#                 Protocolo    Data Finalização  \
# 0       20171200001055820 2017-12-31 23:40:29
# 1       20171200001059152 2017-12-31 23:25:01
# 2       20171200001053020 2017-12-31 22:48:42
# 3       20171200001075260 2017-12-31 22:07:08
# 4       20171200001083060 2017-12-31 21:57:23
# ...                   ...                 ...
# 250426  20161200000544592 2017-01-01 00:01:50
# 250427  20161200000547380 2017-01-01 00:01:49
# 250428  20161200000548640 2017-01-01 00:01:47
# 250429  20161200000550460 2017-01-01 00:01:46
# 250430  20161100000543512 2017-01-01 00:01:46
#
#                                         Fornecedor UF do Consumidor  \
# 0                              Walmart Brasil Ltda               SP
# 1                    Banco Santander (Brasil) S.A.               SP
# 2       Amil Assistencia Médica Internacional S.A.               SP
# 3                                         Tim S.A.               PE
# ...

# %%
df.to_excel("../2017.xlsx", encoding = "utf-8", index=False)
